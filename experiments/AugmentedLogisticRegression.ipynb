# %%
import csv
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.externals import joblib

# %% [markdown]
# # Data preprocessing
# ## Importing heroes.json

# %%
import json
json_file = json.load(open("heroes.json", "rt"))
heroes_list = json_file["heroes"]

# %%
def find_hero(index):
    for hero in heroes_list:
        if int(hero["id"]) == index:
            return hero["localized_name"]

# %%
input_file = open("706d.csv", "rt")
csv_reader = csv.reader(input_file, delimiter=",")
input_data = np.array(list(csv_reader))

# %%
input_data.shape
# Out:
# (506029, 14)

# %% [markdown]
# ## Filtering games according to the desired MMR

# %%
filtered_data = []
for i in range(input_data.shape[0]):
    if int(input_data[i][-1]) >= 4000:
        filtered_data.append(input_data[i])
        
filtered_data = np.array(filtered_data)
print filtered_data.shape
# Out:
# (44709, 14)

# %%
NUMBER_OF_FEATURES = 2 * 114
print NUMBER_OF_FEATURES
# Out:
# 228

# %% [markdown]
# ## Initializing dictionaries for storing winrates

# %%
X_matrix = np.zeros((filtered_data.shape[0], NUMBER_OF_FEATURES), dtype=np.float32)
y_matrix = np.zeros((filtered_data.shape[0], ), dtype=np.int8)

# %%
winrates_radiant = {}
winrates_radiant['apps'] = np.zeros((114, 114), dtype=np.float32)
winrates_radiant['wins'] = np.zeros((114, 114), dtype=np.float32)
winrates_radiant['winrate'] = np.full((114, 114), -1, dtype=np.float32)

# %%
winrates_dire = {}
winrates_dire['apps'] = np.zeros((114, 114), dtype=np.float32)
winrates_dire['wins'] = np.zeros((114, 114), dtype=np.float32)
winrates_dire['winrate'] = np.full((114, 114), -1, dtype=np.float32)

# %%
counter_radiant = {}
counter_radiant['apps'] = np.zeros((114, 114), dtype=np.float32)
counter_radiant['wins'] = np.zeros((114, 114), dtype=np.float32)
counter_radiant['winrate'] = np.full((114, 114), -1, dtype=np.float32)

# %%
counter_dire = {}
counter_dire['apps'] = np.zeros((114, 114), dtype=np.float32)
counter_dire['wins'] = np.zeros((114, 114), dtype=np.float32)
counter_dire['winrate'] = np.full((114, 114), -1, dtype=np.float32)

# %% [markdown]
# ## Converting the filtered data to the 228 features format

# %%
# %%time

for i in range(filtered_data.shape[0]):
    hero_list = filtered_data[i][2:12]
    radiant_win = filtered_data[i][1]
    
    for j in range(5):
        
        X_matrix[i][int(hero_list[j]) - 1] = 1
        
    for j in range(5):
        X_matrix[i][int(hero_list[j + 5]) - 1 + 114] = 1
    
    y_matrix[i] = int(radiant_win)

print "Prepared the data for ML"
# Out:
# Prepared the data for ML
# CPU times: user 328 ms, sys: 64 ms, total: 392 ms
# Wall time: 330 ms

# %% [markdown]
# ## Splitting the data into train and test sets

# %%
X_train, X_test, y_train, y_test = \
    train_test_split(X_matrix, y_matrix, test_size=0.2, random_state=42)

# %% [markdown]
# ## Updating the winrates for synergies and counters if there is enough information

# %%
# %%time

for i in range(X_train.shape[0]):
    if i % 10000 == 9999:
        print (i + 1)
        
    radiant_win = y_train[i]
    heroes = X_train[i]
    
    indices_list = []
    for j in range(len(heroes)):
        if heroes[j] == 1:
            indices_list.append(j)
            
    for j in range(len(indices_list)):
        for k in range(len(indices_list)):
            if j != k and indices_list[j] < 114 and indices_list[k] < 114:
                winrates_radiant['apps'][indices_list[j]][indices_list[k]] += 1
            
                if radiant_win == 1:
                    winrates_radiant['wins'][indices_list[j]][indices_list[k]] += 1
                    
            if j != k and indices_list[j] >= 114 and indices_list[k] >= 114:
                winrates_dire['apps'][indices_list[j] - 114][indices_list[k] - 114] += 1
                
                if radiant_win == 0:
                    winrates_dire['wins'][indices_list[j] - 114][indices_list[k] - 114] += 1
                    
            if indices_list[j] < 114 and indices_list[k] >= 114:
                counter_radiant['apps'][indices_list[j]][indices_list[k] - 114] += 1
                counter_dire['apps'][indices_list[k] - 114][indices_list[j]] += 1
                
                if radiant_win == 1:
                    counter_radiant['wins'][indices_list[j]][indices_list[k] - 114] += 1
                else:
                    counter_dire['wins'][indices_list[k] - 114][indices_list[j]] += 1
# Out:
# 10000
# 20000
# 30000
# CPU times: user 19.1 s, sys: 0 ns, total: 19.1 s
# Wall time: 19.1 s

# %%
for i in range(114):
    for j in range(114):
        if i != j and i != 23 and j != 23:
            if winrates_radiant['apps'][i][j] < 10:
                print "Didn't find enough matches together of heroes %d and %d on radiant" % (i + 1, j + 1)
            else:
                winrates_radiant['winrate'][i][j] = winrates_radiant['wins'][i][j] / float(winrates_radiant['apps'][i][j])
                
            if winrates_dire['apps'][i][j] < 10:
                print "Didn't find enough matches together of heroes %d and %d on dire" % (i + 1, j + 1)
            else:
                winrates_dire['winrate'][i][j] = winrates_dire['wins'][i][j] / float(winrates_dire['apps'][i][j])
                
            if counter_radiant['apps'][i][j] < 10:
                print "Didn't find enough matches together of heroes %d and %d on radiant" % (i + 1, j + 1)
            else:
                counter_radiant['winrate'][i][j] = counter_radiant['wins'][i][j] / float(counter_radiant['apps'][i][j])
                
            if counter_dire['apps'][i][j] < 10:
                print "Didn't find enough matches together of heroes %d and %d on radiant" % (i + 1, j + 1)
            else:
                counter_dire['winrate'][i][j] = counter_dire['wins'][i][j] / float(counter_dire['apps'][i][j])
# Out:
# Didn't find enough matches together of heroes 1 and 38 on radiant
# Didn't find enough matches together of heroes 1 and 67 on radiant
# Didn't find enough matches together of heroes 1 and 72 on dire
# Didn't find enough matches together of heroes 1 and 89 on radiant
# Didn't find enough matches together of heroes 1 and 109 on radiant
# Didn't find enough matches together of heroes 1 and 109 on dire
# Didn't find enough matches together of heroes 2 and 38 on radiant
# Didn't find enough matches together of heroes 2 and 38 on dire
# Didn't find enough matches together of heroes 2 and 52 on radiant
# Didn't find enough matches together of heroes 2 and 78 on dire
# Didn't find enough matches together of heroes 2 and 89 on radiant
# Didn't find enough matches together of heroes 3 and 10 on radiant
# Didn't find enough matches together of heroes 3 and 10 on radiant
# Didn't find enough matches together of heroes 3 and 12 on dire
# Didn't find enough matches together of heroes 3 and 12 on radiant
# Didn't find enough matches together of heroes 3 and 15 on radiant
# Didn't find enough matches together of heroes 3 and 19 on radiant
# Didn't find enough matches together of heroes 3 and 19 on dire
# Didn't find enough matches together of heroes 3 and 19 on radiant
# Didn't find enough matches together of heroes 3 and 20 on radiant
# Didn't find enough matches together of heroes 3 and 20 on dire
# Didn't find enough matches together of heroes 3 and 29 on dire
# Didn't find enough matches together of heroes 6 and 38 on radiant
# Didn't find enough matches together of heroes 6 and 61 on dire
# Didn't find enough matches together of heroes 6 and 66 on radiant
# Didn't find enough matches together of heroes 6 and 66 on radiant
# Didn't find enough matches together of heroes 6 and 67 on radiant
# Didn't find enough matches together of heroes 6 and 73 on radiant
# Didn't find enough matches together of heroes 6 and 77 on radiant
# Didn't find enough matches together of heroes 6 and 77 on dire
# Didn't find enough matches together of heroes 6 and 78 on radiant
# Didn't find enough matches together of heroes 6 and 78 on dire
# Didn't find enough matches together of heroes 6 and 78 on radiant
# Didn't find enough matches together of heroes 6 and 89 on radiant
# Didn't find enough matches together of heroes 6 and 89 on dire
# Didn't find enough matches together of heroes 6 and 103 on radiant
# Didn't find enough matches together of heroes 6 and 103 on dire
# Didn't find enough matches together of heroes 6 and 109 on radiant
# Didn't find enough matches together of heroes 6 and 109 on dire
# Didn't find enough matches together of heroes 9 and 38 on radiant
# Didn't find enough matches together of heroes 9 and 66 on dire
# Didn't find enough matches together of heroes 10 and 3 on radiant
# Didn't find enough matches together of heroes 10 and 3 on radiant
# Didn't find enough matches together of heroes 10 and 12 on radiant
# Didn't find enough matches together of heroes 10 and 12 on dire
# Didn't find enough matches together of heroes 10 and 38 on radiant
# Didn't find enough matches together of heroes 10 and 38 on dire
# Didn't find enough matches together of heroes 10 and 38 on radiant
# Didn't find enough matches together of heroes 10 and 38 on radiant
# Didn't find enough matches together of heroes 10 and 43 on radiant
# Didn't find enough matches together of heroes 10 and 43 on dire
# Didn't find enough matches together of heroes 10 and 52 on radiant
# Didn't find enough matches together of heroes 10 and 52 on dire
# Didn't find enough matches together of heroes 10 and 52 on radiant
# Didn't find enough matches together of heroes 10 and 52 on radiant
# Didn't find enough matches together of heroes 10 and 58 on radiant
# Didn't find enough matches together of heroes 10 and 58 on dire
# Didn't find enough matches together of heroes 10 and 58 on radiant
# Didn't find enough matches together of heroes 10 and 61 on radiant
# Didn't find enough matches together of heroes 10 and 61 on radiant
# Didn't find enough matches together of heroes 10 and 61 on radiant
# Didn't find enough matches together of heroes 10 and 65 on radiant
# Didn't find enough matches together of heroes 10 and 65 on dire
# Didn't find enough matches together of heroes 10 and 65 on radiant
# Didn't find enough matches together of heroes 10 and 66 on radiant
# Didn't find enough matches together of heroes 10 and 66 on dire
# Didn't find enough matches together of heroes 10 and 66 on radiant
# Didn't find enough matches together of heroes 10 and 66 on radiant
# Didn't find enough matches together of heroes 10 and 67 on dire
# Didn't find enough matches together of heroes 10 and 72 on radiant
# Didn't find enough matches together of heroes 10 and 72 on dire
# Didn't find enough matches together of heroes 10 and 73 on radiant
# Didn't find enough matches together of heroes 10 and 77 on radiant
# Didn't find enough matches together of heroes 10 and 77 on dire
# Didn't find enough matches together of heroes 10 and 77 on radiant
# Didn't find enough matches together of heroes 10 and 78 on radiant
# Didn't find enough matches together of heroes 10 and 78 on dire
# Didn't find enough matches together of heroes 10 and 78 on radiant
# Didn't find enough matches together of heroes 10 and 78 on radiant
# Didn't find enough matches together of heroes 10 and 79 on radiant
# Didn't find enough matches together of heroes 10 and 80 on radiant
# Didn't find enough matches together of heroes 10 and 81 on radiant
# Didn't find enough matches together of heroes 10 and 81 on dire
# Didn't find enough matches together of heroes 10 and 89 on dire
# Didn't find enough matches together of heroes 10 and 89 on radiant
# Didn't find enough matches together of heroes 10 and 89 on radiant
# Didn't find enough matches together of heroes 10 and 91 on radiant
# Didn't find enough matches together of heroes 10 and 92 on dire
# Didn't find enough matches together of heroes 10 and 94 on radiant
# Didn't find enough matches together of heroes 10 and 94 on dire
# Didn't find enough matches together of heroes 10 and 102 on radiant
# Didn't find enough matches together of heroes 10 and 102 on radiant
# Didn't find enough matches together of heroes 10 and 103 on radiant
# Didn't find enough matches together of heroes 10 and 103 on dire
# Didn't find enough matches together of heroes 10 and 105 on radiant
# Didn't find enough matches together of heroes 10 and 105 on radiant
# Didn't find enough matches together of heroes 10 and 109 on radiant
# Didn't find enough matches together of heroes 10 and 109 on dire
# Didn't find enough matches together of heroes 10 and 111 on radiant
# Didn't find enough matches together of heroes 10 and 113 on radiant
# Didn't find enough matches together of heroes 12 and 3 on dire
# Didn't find enough matches together of heroes 12 and 3 on radiant
# Didn't find enough matches together of heroes 12 and 6 on radiant
# Didn't find enough matches together of heroes 12 and 6 on dire
# Didn't find enough matches together of heroes 12 and 10 on radiant
# Didn't find enough matches together of heroes 12 and 10 on dire
# Didn't find enough matches together of heroes 12 and 15 on radiant
# Didn't find enough matches together of heroes 12 and 19 on radiant
# Didn't find enough matches together of heroes 12 and 29 on dire
# Didn't find enough matches together of heroes 12 and 29 on radiant
# Didn't find enough matches together of heroes 12 and 37 on radiant
# Didn't find enough matches together of heroes 12 and 38 on radiant
# Didn't find enough matches together of heroes 12 and 38 on dire
# Didn't find enough matches together of heroes 12 and 38 on radiant
# Didn't find enough matches together of heroes 12 and 38 on radiant
# Didn't find enough matches together of heroes 12 and 43 on radiant
# Didn't find enough matches together of heroes 12 and 43 on dire
# Didn't find enough matches together of heroes 12 and 43 on radiant
# Didn't find enough matches together of heroes 12 and 43 on radiant
# Didn't find enough matches together of heroes 12 and 48 on dire
# Didn't find enough matches together of heroes 12 and 49 on dire
# Didn't find enough matches together of heroes 12 and 49 on radiant
# Didn't find enough matches together of heroes 12 and 52 on radiant
# Didn't find enough matches together of heroes 12 and 52 on dire
# Didn't find enough matches together of heroes 12 and 52 on radiant
# Didn't find enough matches together of heroes 12 and 52 on radiant
# Didn't find enough matches together of heroes 12 and 54 on radiant
# Didn't find enough matches together of heroes 12 and 56 on radiant
# Didn't find enough matches together of heroes 12 and 57 on dire
# Didn't find enough matches together of heroes 12 and 58 on radiant
# Didn't find enough matches together of heroes 12 and 58 on dire
# Didn't find enough matches together of heroes 12 and 58 on radiant
# Didn't find enough matches together of heroes 12 and 58 on radiant
# Didn't find enough matches together of heroes 12 and 59 on radiant
# Didn't find enough matches together of heroes 12 and 59 on dire
# Didn't find enough matches together of heroes 12 and 59 on radiant
# Didn't find enough matches together of heroes 12 and 59 on radiant
# Didn't find enough matches together of heroes 12 and 60 on dire
# Didn't find enough matches together of heroes 12 and 60 on radiant
# Didn't find enough matches together of heroes 12 and 61 on radiant
# Didn't find enough matches together of heroes 12 and 61 on dire
# Didn't find enough matches together of heroes 12 and 61 on radiant
# Didn't find enough matches together of heroes 12 and 61 on radiant
# Didn't find enough matches together of heroes 12 and 65 on dire
# Didn't find enough matches together of heroes 12 and 65 on radiant
# Didn't find enough matches together of heroes 12 and 65 on radiant
# Didn't find enough matches together of heroes 12 and 66 on radiant
# Didn't find enough matches together of heroes 12 and 66 on dire
# Didn't find enough matches together of heroes 12 and 66 on radiant
# Didn't find enough matches together of heroes 12 and 66 on radiant
# Didn't find enough matches together of heroes 12 and 67 on dire
# Didn't find enough matches together of heroes 12 and 68 on dire
# Didn't find enough matches together of heroes 12 and 69 on radiant
# Didn't find enough matches together of heroes 12 and 72 on radiant
# Didn't find enough matches together of heroes 12 and 72 on dire
# Didn't find enough matches together of heroes 12 and 72 on radiant
# Didn't find enough matches together of heroes 12 and 73 on radiant
# Didn't find enough matches together of heroes 12 and 73 on dire
# Didn't find enough matches together of heroes 12 and 73 on radiant
# Didn't find enough matches together of heroes 12 and 77 on radiant
# Didn't find enough matches together of heroes 12 and 77 on dire
# Didn't find enough matches together of heroes 12 and 77 on radiant
# Didn't find enough matches together of heroes 12 and 78 on radiant
# Didn't find enough matches together of heroes 12 and 78 on dire
# Didn't find enough matches together of heroes 12 and 78 on radiant
# Didn't find enough matches together of heroes 12 and 78 on radiant
# Didn't find enough matches together of heroes 12 and 79 on radiant
# Didn't find enough matches together of heroes 12 and 79 on dire
# Didn't find enough matches together of heroes 12 and 79 on radiant
# Didn't find enough matches together of heroes 12 and 79 on radiant
# Didn't find enough matches together of heroes 12 and 80 on radiant
# Didn't find enough matches together of heroes 12 and 80 on dire
# Didn't find enough matches together of heroes 12 and 80 on radiant
# Didn't find enough matches together of heroes 12 and 80 on radiant
# Didn't find enough matches together of heroes 12 and 81 on radiant
# Didn't find enough matches together of heroes 12 and 81 on dire
# Didn't find enough matches together of heroes 12 and 82 on radiant
# Didn't find enough matches together of heroes 12 and 82 on dire
# Didn't find enough matches together of heroes 12 and 82 on radiant
# Didn't find enough matches together of heroes 12 and 82 on radiant
# Didn't find enough matches together of heroes 12 and 85 on radiant
# Didn't find enough matches together of heroes 12 and 85 on radiant
# Didn't find enough matches together of heroes 12 and 89 on radiant
# Didn't find enough matches together of heroes 12 and 89 on dire
# Didn't find enough matches together of heroes 12 and 89 on radiant
# Didn't find enough matches together of heroes 12 and 89 on radiant
# Didn't find enough matches together of heroes 12 and 91 on radiant
# Didn't find enough matches together of heroes 12 and 91 on radiant
# Didn't find enough matches together of heroes 12 and 91 on radiant
# Didn't find enough matches together of heroes 12 and 92 on radiant
# Didn't find enough matches together of heroes 12 and 92 on dire
# Didn't find enough matches together of heroes 12 and 92 on radiant
# Didn't find enough matches together of heroes 12 and 94 on radiant
# Didn't find enough matches together of heroes 12 and 94 on dire
# Didn't find enough matches together of heroes 12 and 96 on dire
# Didn't find enough matches together of heroes 12 and 103 on radiant
# Didn't find enough matches together of heroes 12 and 103 on dire
# Didn't find enough matches together of heroes 29 and 47 on radiant
# Didn't find enough matches together of heroes 29 and 52 on dire
# Didn't find enough matches together of heroes 29 and 55 on radiant
# Didn't find enough matches together of heroes 29 and 55 on dire
# Didn't find enough matches together of heroes 29 and 58 on radiant
# Didn't find enough matches together of heroes 29 and 58 on radiant
# Didn't find enough matches together of heroes 29 and 58 on radiant
# Didn't find enough matches together of heroes 29 and 60 on radiant
# Didn't find enough matches together of heroes 29 and 61 on radiant
# Didn't find enough matches together of heroes 29 and 61 on dire
# Didn't find enough matches together of heroes 29 and 61 on radiant
# Didn't find enough matches together of heroes 29 and 65 on radiant
# Didn't find enough matches together of heroes 29 and 65 on dire
# Didn't find enough matches together of heroes 29 and 65 on radiant
# Didn't find enough matches together of heroes 29 and 66 on radiant
# Didn't find enough matches together of heroes 29 and 66 on dire
# Didn't find enough matches together of heroes 29 and 66 on radiant
# Didn't find enough matches together of heroes 29 and 66 on radiant
# Didn't find enough matches together of heroes 29 and 69 on radiant
# Didn't find enough matches together of heroes 29 and 69 on dire
# Didn't find enough matches together of heroes 29 and 72 on dire
# Didn't find enough matches together of heroes 29 and 77 on radiant
# Didn't find enough matches together of heroes 29 and 78 on radiant
# Didn't find enough matches together of heroes 29 and 78 on dire
# Didn't find enough matches together of heroes 29 and 78 on radiant
# Didn't find enough matches together of heroes 29 and 78 on radiant
# Didn't find enough matches together of heroes 29 and 79 on dire
# Didn't find enough matches together of heroes 29 and 80 on radiant
# Didn't find enough matches together of heroes 29 and 81 on radiant
# Didn't find enough matches together of heroes 29 and 85 on radiant
# Didn't find enough matches together of heroes 29 and 85 on dire
# Didn't find enough matches together of heroes 29 and 89 on radiant
# Didn't find enough matches together of heroes 29 and 89 on dire
# Didn't find enough matches together of heroes 29 and 89 on radiant
# Didn't find enough matches together of heroes 29 and 89 on radiant
# Didn't find enough matches together of heroes 29 and 92 on dire
# Didn't find enough matches together of heroes 29 and 92 on radiant
# Didn't find enough matches together of heroes 29 and 92 on radiant
# Didn't find enough matches together of heroes 29 and 94 on radiant
# Didn't find enough matches together of heroes 29 and 96 on radiant
# Didn't find enough matches together of heroes 29 and 96 on dire
# Didn't find enough matches together of heroes 29 and 98 on radiant
# Didn't find enough matches together of heroes 29 and 98 on dire
# Didn't find enough matches together of heroes 29 and 100 on radiant
# Didn't find enough matches together of heroes 29 and 102 on dire
# Didn't find enough matches together of heroes 29 and 103 on radiant
# Didn't find enough matches together of heroes 29 and 103 on dire
# Didn't find enough matches together of heroes 29 and 103 on radiant
# Didn't find enough matches together of heroes 29 and 103 on radiant
# Didn't find enough matches together of heroes 29 and 105 on dire
# Didn't find enough matches together of heroes 29 and 105 on radiant
# Didn't find enough matches together of heroes 29 and 105 on radiant
# Didn't find enough matches together of heroes 29 and 108 on radiant
# Didn't find enough matches together of heroes 29 and 108 on dire
# Didn't find enough matches together of heroes 29 and 112 on radiant
# Didn't find enough matches together of heroes 30 and 3 on radiant
# Didn't find enough matches together of heroes 30 and 38 on radiant
# Didn't find enough matches together of heroes 30 and 38 on dire
# Didn't find enough matches together of heroes 30 and 43 on dire
# Didn't find enough matches together of heroes 114 and 78 on radiant
# Didn't find enough matches together of heroes 114 and 78 on dire
# Didn't find enough matches together of heroes 114 and 79 on radiant
# Didn't find enough matches together of heroes 114 and 79 on dire
# Didn't find enough matches together of heroes 114 and 89 on radiant
# Didn't find enough matches together of heroes 114 and 89 on radiant
# Didn't find enough matches together of heroes 114 and 91 on dire
# Didn't find enough matches together of heroes 114 and 103 on dire
# Didn't find enough matches together of heroes 114 and 105 on dire
# Didn't find enough matches together of heroes 114 and 111 on radiant

# %% [markdown]
# ## Only save the advantages (current_winrate - global_winrate)

# %%
for j in range(114):
    if j != 23:
        apps_radiant = np.sum(winrates_radiant['apps'][j])
        wins_radiant = np.sum(winrates_radiant['wins'][j])

        global_radiant_winrate = wins_radiant / apps_radiant

        for i in range(len(winrates_radiant['winrate'][j])):
            if winrates_radiant['winrate'][j][i] != 0.:
                winrates_radiant['winrate'][j][i] -= global_radiant_winrate

        apps_dire = np.sum(winrates_dire['apps'][j])
        wins_dire = np.sum(winrates_dire['wins'][j])

        global_dire_winrate = wins_dire / apps_dire

        for i in range(len(winrates_dire['winrate'][j])):
            if winrates_dire['winrate'][j][i] != 0.:
                winrates_dire['winrate'][j][i] -= global_dire_winrate

# %% [markdown]
# ## Augment game data

# %%
def augment_synergy(hero_list):
    syn_rad = 0
    syn_dire = 0
    cnt_rad = 0
    cnt_dire = 0
    
    for i in range(5):
        for j in range(5):
            if i > j:
                syn_rad += winrates_radiant['winrate'][int(hero_list[i]) - 1][int(hero_list[j]) - 1]
                syn_dire += winrates_dire['winrate'][int(hero_list[i + 5]) - 1][int(hero_list[j + 5]) - 1]
                
            cnt_rad += counter_radiant['winrate'][int(hero_list[i]) - 1][int(hero_list[j + 5]) - 1]
            cnt_dire += counter_dire['winrate'][int(hero_list[j + 5]) - 1][int(hero_list[i]) - 1]
    
    return (syn_rad - syn_dire, cnt_rad - cnt_dire)

# %% [markdown]
# ## Augment the train data set

# %%
# %%time

X_train_aug = np.zeros((X_train.shape[0], X_train.shape[1] + 2), dtype=np.float32)
X_train_aug[:,:-2] = X_train

for i in range(X_train.shape[0]):
    if i % 10000 == 9999:
        print (i + 1)
        
    not_indexed = []
    for j in range(len(X_train_aug[i])):
        if X_train_aug[i][j] == 1:
            not_indexed.append(j % 114 + 1)
            
    X_train_aug[i][-2:] = augment_synergy(not_indexed)
# Out:
# 10000
# 20000
# 30000
# CPU times: user 11.3 s, sys: 300 ms, total: 11.6 s
# Wall time: 10.9 s

# %% [markdown]
# ## Augment the test data set

# %%
# %%time

X_test_aug = np.zeros((X_test.shape[0], X_test.shape[1] + 2), dtype=np.float32)
X_test_aug[:,:-2] = X_test

for i in range(X_test.shape[0]):
    if i % 10000 == 9999:
        print (i + 1)
        
    not_indexed = []
    for j in range(len(X_test_aug[i])):
        if X_test_aug[i][j] == 1:
            not_indexed.append(j % 114 + 1)
            
    X_test_aug[i][-2:] = augment_synergy(not_indexed)
# Out:
# CPU times: user 2.56 s, sys: 16 ms, total: 2.58 s
# Wall time: 2.56 s

# %%
print "X train shape: ", X_train.shape
print "X test shape: ", X_test.shape
print "y train shape: ", y_train.shape
print "y test shape: ", y_test.shape
# Out:
# X train shape:  (35767, 228)
# X test shape:  (8942, 228)
# y train shape:  (35767,)
# y test shape:  (8942,)

# %% [markdown]
# # Train the models
# ## Train the non-augmented model

# %%
model = LogisticRegression(n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
probabilities = model.predict_proba(X_test)
roc_auc_score = metrics.roc_auc_score(y_test, probabilities[:, 1])

# %%
print roc_auc_score
# Out:
# 0.600901330557

# %% [markdown]
# ## Train the augmented model

# %%
model_aug = LogisticRegression(n_jobs=-1)
model_aug.fit(X_train_aug, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
probabilities_aug = model_aug.predict_proba(X_test_aug)
roc_auc_score_aug = metrics.roc_auc_score(y_test, probabilities_aug[:, 1])

# %%
print roc_auc_score_aug
# Out:
# 0.561353197022

# %% [markdown]
# ## Make predictions with the augmented model
# Higher score means higher chance for dire to win
#
# Need to implement for radiant too

# %%
#hero_list = [102, 65, 74, 77, 86, 94, 59, 13, 84] # github example
hero_list = [114, 108, 16, 95, 74, 88, 70, 83, 9]

# %%
hero_dict = {}
for i in range(114):
    new_list = np.zeros(230)
    if (i + 1) not in hero_list and (i + 1) != 24:
        hero_list.append(i + 1)
        
        for j in range(10):
            if j < 5:
                new_list[hero_list[j] - 1] = 1
            else:
                new_list[hero_list[j] - 1 + 114] = 1
            
        synergy = augment_synergy(hero_list)
        new_list[228] = synergy[0]
        new_list[229] = synergy[1]
        del hero_list[-1]
        
        hero_dict[i + 1] = model_aug.predict_proba(new_list.reshape(1, -1))[0][0]

# %%
import operator
sorted_dict = sorted(hero_dict.items(), key=operator.itemgetter(1), reverse=True)

for (k, v) in sorted_dict:
    print (find_hero(k) ,v)
# Out:
# (u'Gyrocopter', 0.8958928681384527)
# (u'Naga Siren', 0.88783839807396925)
# (u'Drow Ranger', 0.85680400114301702)
# (u'Leshrac', 0.7929109222697508)
# (u'Batrider', 0.77871637570125363)
# (u'Visage', 0.72345539974493378)
# (u'Night Stalker', 0.71261654812637432)
# (u'Sniper', 0.70306277109684223)
# (u'Enchantress', 0.68928772562426288)
# (u'Jakiro', 0.67998715337846771)
# (u'Skywrath Mage', 0.66547708386593296)
# (u'Enigma', 0.66358006888537791)
# (u'Necrophos', 0.66125057094007611)
# (u'Bane', 0.65595757320725978)
# (u'Wisp', 0.64593813574314196)
# (u'Riki', 0.64577832280720093)
# (u'Dark Seer', 0.64524807891006497)
# (u'Abaddon', 0.62014120268075423)
# (u'Elder Titan', 0.61708465872823848)
# (u'Phantom Lancer', 0.61579160269462396)
# (u'Phoenix', 0.61175243592281392)
# (u'Bloodseeker', 0.60888866001556008)
# (u'Spirit Breaker', 0.60459476306908955)
# (u'Medusa', 0.60299879897815722)
# (u'Warlock', 0.58835982616106719)
# (u'Crystal Maiden', 0.58342041158006441)
# (u'Witch Doctor', 0.55878106526419291)
# (u'Brewmaster', 0.55280650353658634)
# (u'Zeus', 0.54808722084834971)
# (u'Timbersaw', 0.54202321419255473)
# (u'Tinker', 0.53708782307789238)
# (u'Axe', 0.53619706976935422)
# (u'Bounty Hunter', 0.53219781313430503)
# (u'Storm Spirit', 0.53111077116863892)
# (u'Death Prophet', 0.52783128497889886)
# (u'Faceless Void', 0.52213906069034355)
# (u'Broodmother', 0.5208254377958399)
# (u'Windranger', 0.5143129154213707)
# (u'Venomancer', 0.51356782178163385)
# (u'Anti-Mage', 0.51138454017270296)
# (u'Outworld Devourer', 0.50886016034310355)
# (u'Lina', 0.50675899220005827)
# (u'Weaver', 0.503865054156308)
# (u'Viper', 0.5016159608163101)
# (u'Spectre', 0.50053612624293664)
# (u'Templar Assassin', 0.4923279250257282)
# (u'Puck', 0.49220685493804772)
# (u'Shadow Fiend', 0.49214871166768281)
# (u'Pugna', 0.48459049836659374)
# (u'Lich', 0.47849506447581391)
# (u'Disruptor', 0.47767127234518625)
# (u'Meepo', 0.47626548167999527)
# (u'Pudge', 0.47626099383165799)
# (u'Slark', 0.47508202464593186)
# (u'Arc Warden', 0.47217755400065442)
# (u'Rubick', 0.47158770935983418)
# (u'Ember Spirit', 0.46975806400439069)
# (u"Nature's Prophet", 0.46679530172621631)
# (u'Dazzle', 0.46050937253247859)
# (u'Doom', 0.45198305382703652)
# (u'Juggernaut', 0.45046632056687597)
# (u'Tidehunter', 0.44648929559613892)
# (u'Terrorblade', 0.43782595384105605)
# (u'Centaur Warrunner', 0.4316409343737404)
# (u'Tusk', 0.42577921139174335)
# (u'Slardar', 0.42298419119710617)
# (u'Bristleback', 0.42272576998264078)
# (u'Omniknight', 0.41835304794908856)
# (u'Ogre Magi', 0.41667330531797186)
# (u'Phantom Assassin', 0.41280900423685241)
# (u'Keeper of the Light', 0.41168312873256552)
# (u'Magnus', 0.40601773268957719)
# (u'Sven', 0.40565256939996674)
# (u'Lycanthrope', 0.40554455599435157)
# (u'Earthshaker', 0.40305821727761937)
# (u'Morphling', 0.39896836687714998)
# (u'Skeleton King', 0.38462839561850182)
# (u'Shadow Demon', 0.37875967408056688)
# (u'Silencer', 0.37331538569031897)
# (u'Vengeful Spirit', 0.3689690500413747)
# (u'Lifestealer', 0.36886304233401634)
# (u'Kunkka', 0.36861316168151492)
# (u'Oracle', 0.36540025730957404)
# (u'Earth Spirit', 0.3649072407091386)
# (u'Chaos Knight', 0.36324793144278356)
# (u'Undying', 0.36246278915922303)
# (u'Clockwerk', 0.3603224341890009)
# (u'Lion', 0.35610653297700634)
# (u'Luna', 0.35395536590229915)
# (u'Queen of Pain', 0.3538167087159021)
# (u'Shadow Shaman', 0.34638562707456133)
# (u'Winter Wyvern', 0.3366077699854213)
# (u'Tiny', 0.32387771933563347)
# (u'Legion Commander', 0.29754413094744936)
# (u'Ancient Apparition', 0.29599530631089588)
# (u'Clinkz', 0.28492719421122115)
# (u'Dragon Knight', 0.28447219624335651)
# (u'Lone Druid', 0.28101348751255595)
# (u'Beastmaster', 0.26445079078284606)
# (u'Techies', 0.23796488135323779)
# (u'Razor', 0.20412177079315952)
# (u'Huskar', 0.18570944853976434)
# (u'Alchemist', 0.17017435259186886)
# (u'Chen', 0.091639235964995569)
